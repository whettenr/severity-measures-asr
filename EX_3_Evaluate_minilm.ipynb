# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline

# %%
with open('MiniLM_history/history_cos.pkl', 'rb') as handle:
    history_cos = pickle.load(handle)

# %%
with open('MiniLM_history/history_base.pkl', 'rb') as handle:
    history_base = pickle.load(handle)

# %%
with open('MiniLM_history/history_cossquared.pkl', 'rb') as handle:
    history_cos2 = pickle.load(handle)

# %%
with open('MiniLM_history/history_mini_ctc001cos.pkl', 'rb') as handle:
    history_only_cos = pickle.load(handle)

# %%
len(history_cos['losses'])
# Out:
# 589500

# %%
plt.plot(np.arange(0, 589500, 1), history_cos['losses'])

# %%
plt.plot(np.arange(0, 589500, 1), history_base['losses'])

# %%
plt.plot(np.arange(0, 589500, 1), history_cos2['losses'])

# %%
plt.plot(np.arange(0, 589500, 1), history_only_cos['losses'])

# %%
np.mean(history_cos['losses'][-2000:])
# Out:
# 22.089403772592544

# %%
np.mean(history_base['losses'][-2000:])
# Out:
# 22.140692232608796

# %%
np.mean(history_cos2['losses'][-2000:])
# Out:
# 20.349822185516356

# %%
np.mean(history_only_cos['losses'][-2000:])
# Out:
# 0.30247114635421896

# %%
history_base.keys()
# Out:
# dict_keys(['losses', 'train_wer', 'train_cos_loss', 'train_cos_dis', 'val_wer', 'val_cos_loss', 'val_cos_dis'])

# %%
# history_base['val_wer']
# history_cos['val_wer']

# %% [markdown]
# # Base model

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_wer'])
plt.plot(x, history_base['val_wer'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('Base WER')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_cos_loss'])
plt.plot(x, history_base['val_cos_loss'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Base Cos Loss')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_cos_dis'])
plt.plot(x, history_base['val_cos_dis'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Base Cos Dis')
plt.show()

# %% [markdown]
# # CTC + Cos model

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos['train_wer'])
plt.plot(x, history_cos['val_wer'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('CTC + Cos WER')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos['train_cos_loss'])
plt.plot(x, history_cos['val_cos_loss'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Base Cos Loss')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos['train_cos_dis'])
plt.plot(x, history_cos['val_cos_dis'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Base Cos Dis')
plt.show()

# %% [markdown]
# ## Cos2 Model

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos2['train_wer'])
plt.plot(x, history_cos2['val_wer'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('CTC + Cos^2 WER')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos2['train_cos_loss'])
plt.plot(x, history_cos2['val_cos_loss'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Base Cos Loss')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos2['train_cos_dis'])
plt.plot(x, history_cos2['val_cos_dis'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Base Cos Dis')
plt.show()

# %% [markdown]
# ## Only Cos

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_only_cos['train_wer'])
plt.plot(x, history_only_cos['val_wer'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('Mostly Cos WER')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_only_cos['train_cos_loss'])
plt.plot(x, history_only_cos['val_cos_loss'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Mostly Cos Loss')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_only_cos['train_cos_dis'])
plt.plot(x, history_only_cos['val_cos_dis'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Mostly Cos Dis')
plt.show()

# %% [markdown]
# # Comparing

# %% [markdown]
# ### Cos distance

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_cos_dis'], label='Base Model')
plt.plot(x, history_cos['train_cos_dis'], label='CTC + Cos Model')
plt.plot(x, history_cos2['train_cos_dis'], label='CTC + Cos^2 Model')
plt.plot(x, history_only_cos['train_cos_dis'], label='CTC * 1e-3 + Cos Model')
# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Model Comparison: Training Cos Dis')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['val_cos_dis'], label='Base Model')
plt.plot(x, history_cos['val_cos_dis'], label='CTC + Cos Model')
plt.plot(x, history_cos2['val_cos_dis'], label='CTC + Cos^2 Model')
plt.plot(x, history_only_cos['val_cos_dis'], label='CTC * 1e-3 + Cos Model')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Model Comparison: Validation Cos Dis')
plt.show()

# %% [markdown]
# ## Cos loss

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_cos_loss'], label='Base Model')
plt.plot(x, history_cos['train_cos_loss'], label='CTC + Cos Model')
plt.plot(x, history_cos2['train_cos_loss'], label='CTC + Cos^2 Model')
plt.plot(x, history_only_cos['train_cos_loss'], label='CTC * 1e-3 + Cos Model')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Model Comparison: Train Cos Loss')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['val_cos_loss'], label='Base Model')
plt.plot(x, history_cos['val_cos_loss'], label='CTC + Cos Model')
plt.plot(x, history_cos2['val_cos_loss'], label='CTC + Cos^2 Model')
plt.plot(x, history_only_cos['val_cos_loss'], label='CTC * 1e-3 + Cos Model')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Model Comparison: Validation Cos Loss')
plt.show()

# %% [markdown]
# ## WER

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_wer'], label='Base Model')
plt.plot(x, history_cos['train_wer'], label='CTC + Cos Model')
plt.plot(x, history_cos2['train_wer'], label='CTC + Cos^2 Model')
plt.plot(x, history_only_cos['train_wer'], label='CTC * 1e-3 + Cos Model')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('Model Comparison: Train WER')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['val_wer'], label='Base Model')
plt.plot(x, history_cos['val_wer'], label='CTC + Cos Model')
plt.plot(x, history_cos2['val_wer'], label='CTC + Cos^2 Model')
plt.plot(x, history_only_cos['val_wer'], label='CTC * 1e-3 + Cos Model')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('Model Comparison: Validation WER')
plt.show()

# %%
history_base['val_wer'][-5:]
# Out:
# [0.4542152128649271,
#  0.4486333229965002,
#  0.44889912727594916,
#  0.4494750365480884,
#  0.4600629070128029]

# %%
history_cos['val_wer'][-5:]
# Out:
# [0.4331629908552985,
#  0.4408732293347678,
#  0.43513537744306974,
#  0.43446297292451136,
#  0.42859064012910164]

# %%
history_cos2['val_wer'][-5:]
# Out:
# [0.4381615850900208,
#  0.43359268976748394,
#  0.42875237492083595,
#  0.4295213969058174,
#  0.42906903103229893]

# %% [markdown]
# # 512

# %%
with open('MiniLM_history/history_512_base_seed1.pkl', 'rb') as handle:
    history_512_base = pickle.load(handle)

# %%
with open('MiniLM_history/history_512_ctcbycos_seed1_last5.pkl', 'rb') as handle:
    history_512_ctcbycos_last5 = pickle.load(handle)

# %%
with open('MiniLM_history/history_512_ctcbycos_seed1_all.pkl', 'rb') as handle:
    history_512_ctcbycos_all = pickle.load(handle)

# %%
len(history_512_base['train_cos_dis'])

history_512_ctcbycos_last5['train_cos_dis'] = history_512_base['train_cos_dis'][:-7] + history_512_ctcbycos_last5['train_cos_dis']
history_512_ctcbycos_last5['val_cos_dis'] = history_512_base['val_cos_dis'][:-7] + history_512_ctcbycos_last5['val_cos_dis']

history_512_ctcbycos_last5['train_wer'] = history_512_base['train_wer'][:-7] + history_512_ctcbycos_last5['train_wer']
history_512_ctcbycos_last5['val_wer'] = history_512_base['val_wer'][:-7] + history_512_ctcbycos_last5['val_wer']

# %%
history_512_ctcbycos_all['train_wer'][-5:]
# Out:
# [0.027630063592208702,
#  0.01888738671073056,
#  0.020379550348004608,
#  0.1388313053928196,
#  0.04711832156627109]

# %%
history_512_ctcbycos_all['val_wer'][-5:]
# Out:
# [0.24026632567573525,
#  0.23197671855020063,
#  0.23435777591604567,
#  0.3165924423475462,
#  0.25384717139203666]

# %%
history_512_base['train_wer'][-5:]
# Out:
# [0.01832657353162085,
#  0.015086875970156727,
#  0.03842071002954284,
#  0.022432527164388365,
#  0.058314556106354214]

# %%
history_512_base['val_wer'][-5:]
# Out:
# [0.22584770051589576,
#  0.2254949512765113,
#  0.2545526698708056,
#  0.23294677895850788,
#  0.26830989020679924]

# %%
history_512_ctcbycos_last5['train_wer'][-5:]
# Out:
# [0.035716789344549596,
#  0.03090481197736718,
#  0.0661158680086125,
#  0.022452556206499424,
#  0.016619097691652897]

# %%
history_512_ctcbycos_last5['val_wer'][-5:]
# Out:
# [0.240839543189735,
#  0.2428678513161956,
#  0.2690153886855681,
#  0.23078618986727809,
#  0.22620044975528023]

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_512_base['train_cos_dis'], label='Base Model')
plt.plot(x, history_512_ctcbycos_last5['train_cos_dis'], label='CTC * Cos Model')
plt.plot(x, history_512_ctcbycos_all['train_cos_dis'], label='CTC * Cos Model All')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Cos Dis (Train)')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_512_base['val_cos_dis'], label='Base Model')
plt.plot(x, history_512_ctcbycos_last5['val_cos_dis'], label='CTC * Cos Model')
plt.plot(x, history_512_ctcbycos_all['val_cos_dis'], label='CTC * Cos Model All')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Cos Dis (Validation)')
plt.show()

# %% [markdown]
# WER

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_512_base['train_wer'], label='Base Model')
plt.plot(x, history_512_ctcbycos_last5['train_wer'], label='CTC * Cos Model')
plt.plot(x, history_512_ctcbycos_all['train_wer'], label='CTC * Cos Model All')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('WER (Train)')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_512_base['val_wer'], label='Base Model')
plt.plot(x, history_512_ctcbycos_last5['val_wer'], label='CTC * Cos Model')
plt.plot(x, history_512_ctcbycos_all['val_wer'], label='CTC * Cos Model All')

# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('WER (Validation)')
plt.show()

# %%
(history_512_base['train_wer'][-1] - history_512_ctcbycos_last5['train_wer'][-1])/ history_512_base['train_wer'][-1]
# Out:
# 0.7150094453031084

# %%
(history_512_base['val_wer'][-1] - history_512_ctcbycos_last5['val_wer'][-1] )/ history_512_base['val_wer'][-1]
# Out:
# 0.15694330320460143

# %%
(history_512_base['train_cos_dis'][-1] - history_512_ctcbycos_last5['train_cos_dis'][-1] )/ history_512_base['train_cos_dis'][-1]
# Out:
# 0.7178700880406276

# %%
(history_512_base['val_cos_dis'][-1] - history_512_ctcbycos_last5['val_cos_dis'][-1] )/ history_512_base['val_cos_dis'][-1]
# Out:
# 0.14863653451770112

# %%
history_512_ctcbycos_last5['val_wer'][-1]
history_512_ctcbycos_last5['val_cos_dis'][-1]
# Out:
# 0.22620044975528023

# %%
26628480 / 2800000
# Out:
# 9.510171428571429

# %%
history_512_ctcbycos_last5['val_wer'][-1]
# Out:
# 0.22620044975528023

# %%
history_512_base['val_wer'][-1]
# Out:
# 0.26830989020679924

# %%
history_512_ctcbycos_last5['val_cos_dis'][-1]
# Out:
# 0.2122043980896928

# %%
history_512_base['val_cos_dis'][-1]
# Out:
# 0.24925241297437944

# %%
history_512_ctcbycos_last5['train_wer'][-1]
# Out:
# 0.016619097691652897

# %%
history_512_base['train_wer'][-1]
# Out:
# 0.058314556106354214

# %%
history_512_ctcbycos_last5['train_cos_dis'][-1]
# Out:
# 0.014397303318957133

# %%
history_512_base['train_cos_dis'][-1]
# Out:
# 0.05103075820273318
