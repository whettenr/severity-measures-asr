# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline

# %%
with open('history_cos.pkl', 'rb') as handle:
    history_cos = pickle.load(handle)

# %%
with open('history_base.pkl', 'rb') as handle:
    history_base = pickle.load(handle)

# %%
len(history_cos['losses'])
# Out:
# 589500

# %%
plt.plot(np.arange(0, 589500, 1), history_cos['losses'])

# %%
plt.plot(np.arange(0, 589500, 1), history_base['losses'])

# %%
np.mean(history_cos['losses'][-2000:])
# Out:
# 22.089403772592544

# %%
np.mean(history_base['losses'][-2000:])
# Out:
# 22.140692232608796

# %%
history_base.keys()
# Out:
# dict_keys(['losses', 'train_wer', 'train_cos_loss', 'train_cos_dis', 'val_wer', 'val_cos_loss', 'val_cos_dis'])

# %%
# history_base['val_wer']
# history_cos['val_wer']

# %% [markdown]
# # Base model

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_wer'])
plt.plot(x, history_base['val_wer'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('Base WER')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_cos_loss'])
plt.plot(x, history_base['val_cos_loss'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Base Cos Loss')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_cos_dis'])
plt.plot(x, history_base['val_cos_dis'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Base Cos Dis')
plt.show()

# %% [markdown]
# # CTC + Cos model

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos['train_wer'])
plt.plot(x, history_cos['val_wer'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('CTC + Cos WER')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos['train_cos_loss'])
plt.plot(x, history_cos['val_cos_loss'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Base Cos Loss')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_cos['train_cos_dis'])
plt.plot(x, history_cos['val_cos_dis'])
# plt.plot(x, y2, '-.')

plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Base Cos Dis')
plt.show()

# %% [markdown]
# # Comparing

# %% [markdown]
# ### Cos distance

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_cos_dis'], label='Base Model')
plt.plot(x, history_cos['train_cos_dis'], label='CTC + Cos Model')
# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Base vs CTC + Cos Model: Training Cos Dis')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['val_cos_dis'], label='Base Model')
plt.plot(x, history_cos['val_cos_dis'], label='CTC + Cos Model')
# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Dis")
plt.title('Base vs CTC + Cos Model: Validation Cos Dis')
plt.show()

# %% [markdown]
# ## Cos loss

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_cos_loss'], label='Base Model')
plt.plot(x, history_cos['train_cos_loss'], label='CTC + Cos Model')
# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Base vs CTC + Cos Model: Train Cos Loss')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['val_cos_loss'], label='Base Model')
plt.plot(x, history_cos['val_cos_loss'], label='CTC + Cos Model')
# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("Cos Loss")
plt.title('Base vs CTC + Cos Model: Validation Cos Loss')
plt.show()

# %% [markdown]
# ## WER

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['train_wer'], label='Base Model')
plt.plot(x, history_cos['train_wer'], label='CTC + Cos Model')
# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('Base vs CTC + Cos Model: Train WER')
plt.show()

# %%
x = np.arange(0, 50, 1)

plt.plot(x, history_base['val_wer'], label='Base Model')
plt.plot(x, history_cos['val_wer'], label='CTC + Cos Model')
# plt.plot(x, y2, '-.')

plt.legend(loc='upper right')
plt.xlabel("Epoch")
plt.ylabel("WER")
plt.title('Base vs CTC + Cos Model: Validation WER')
plt.show()

# %%
history_base['val_wer'][-5:]
# Out:
# [0.4542152128649271,
#  0.4486333229965002,
#  0.44889912727594916,
#  0.4494750365480884,
#  0.4600629070128029]

# %%
history_cos['val_wer'][-5:]
# Out:
# [0.4331629908552985,
#  0.4408732293347678,
#  0.43513537744306974,
#  0.43446297292451136,
#  0.42859064012910164]
